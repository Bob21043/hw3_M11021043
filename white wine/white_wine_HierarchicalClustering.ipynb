# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/drive/MyDrive/資料探勘/作業2/hw3/Wine Quality Data Set.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.0              0.27         0.36  ...       0.45      8.8        6
# 1               6.3              0.30         0.34  ...       0.49      9.5        6
# 2               8.1              0.28         0.40  ...       0.44     10.1        6
# 3               7.2              0.23         0.32  ...       0.40      9.9        6
# 4               7.2              0.23         0.32  ...       0.40      9.9        6
# ...             ...               ...          ...  ...        ...      ...      ...
# 4893            6.2              0.21         0.29  ...       0.50     11.2        6
# 4894            6.6              0.32         0.36  ...       0.46      9.6        5
# 4895            6.5              0.24         0.19  ...       0.46      9.4        6
# 4896            5.5              0.29         0.30  ...       0.38     12.8        7
# 4897            6.0              0.21         0.38  ...       0.32     11.8        6
#
# [4898 rows x 12 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df_1=scaler.fit_transform(df)
df_2=pd.DataFrame(df_1,columns=df.columns)
df_2
# Out:
#       fixed acidity  volatile acidity  ...   alcohol   quality
# 0          0.307692          0.186275  ...  0.129032  0.500000
# 1          0.240385          0.215686  ...  0.241935  0.500000
# 2          0.413462          0.196078  ...  0.338710  0.500000
# 3          0.326923          0.147059  ...  0.306452  0.500000
# 4          0.326923          0.147059  ...  0.306452  0.500000
# ...             ...               ...  ...       ...       ...
# 4893       0.230769          0.127451  ...  0.516129  0.500000
# 4894       0.269231          0.235294  ...  0.258065  0.333333
# 4895       0.259615          0.156863  ...  0.225806  0.500000
# 4896       0.163462          0.205882  ...  0.774194  0.666667
# 4897       0.211538          0.127451  ...  0.612903  0.500000
#
# [4898 rows x 12 columns]

# %%
from sklearn.cluster import AgglomerativeClustering
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
Start=time.time()
agg = AgglomerativeClustering(n_clusters=3,affinity='euclidean',linkage='ward').fit(df_2)
agglb=agg.fit(df_2)
y_agg=agglb.fit_predict(df_2)
End=time.time()
print(agglb)
print(End-Start)
# Out:
# AgglomerativeClustering(n_clusters=3)
# 2.7140212059020996

# %%
len(y_agg)
# Out:
# 4898

# %%
agg_add = df_2
agg_add["Cluster"] = y_agg
agg_add
# Out:
#       fixed acidity  volatile acidity  citric acid  ...   alcohol   quality  Cluster
# 0          0.307692          0.186275     0.216867  ...  0.129032  0.500000        1
# 1          0.240385          0.215686     0.204819  ...  0.241935  0.500000        1
# 2          0.413462          0.196078     0.240964  ...  0.338710  0.500000        1
# 3          0.326923          0.147059     0.192771  ...  0.306452  0.500000        1
# 4          0.326923          0.147059     0.192771  ...  0.306452  0.500000        1
# ...             ...               ...          ...  ...       ...       ...      ...
# 4893       0.230769          0.127451     0.174699  ...  0.516129  0.500000        0
# 4894       0.269231          0.235294     0.216867  ...  0.258065  0.333333        1
# 4895       0.259615          0.156863     0.114458  ...  0.225806  0.500000        2
# 4896       0.163462          0.205882     0.180723  ...  0.774194  0.666667        0
# 4897       0.211538          0.127451     0.228916  ...  0.612903  0.500000        0
#
# [4898 rows x 13 columns]

# %%
agg_results = agg_add.groupby("Cluster").sum()
agg_results
# Out:
#          fixed acidity  volatile acidity  ...      alcohol      quality
# Cluster                                   ...
# 0           501.418269        343.955882  ...  1094.545699  1081.833333
# 1           768.461538        520.431373  ...   667.572043  1070.666667
# 2           168.807692         87.558824  ...   224.153226   196.833333
#
# [3 rows x 12 columns]

# %%
purityList=[]
total=0
for i in range(3):
    purity = agg_results.loc[i].max()/agg_results.loc[i].sum()
    purityList.append(purity)
    total = total + agg_results.loc[i].sum()

print("純度:\n",purityList)
print("總和:\n",total)
# Out:
# 純度:
#  [0.18673207848165305, 0.14060573453446998, 0.16750112284771618]
# 總和:
#  14995.489078993134

# %%
Total_purity=0
for i in range(len(purityList)):
    Total_purity = Total_purity+purityList[i]*(agg_results.loc[i].sum()/total)
print("總純度:\n",Total_purity)
# Out:
# 總純度:
#  0.16103623521879462

# %%
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(df_2, method  = "ward"))
plt.title('Hierarchical Clustering')
plt.xlabel('Sample')
plt.ylabel('Clusting')
plt.show()
